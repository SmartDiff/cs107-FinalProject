# %% [markdown]
# # Milestone 2 Progress Report

# %% [markdown]
# ## Task Assignment
# The tasks below are ordered by their priority.
#
# 1. Pseudocode of the differentiation function - *Everyone (Finished, similar to HW4)*
# 2. Brainstorm about project extensions - *Everyone (Finished)*
# 3. Implement operator overloading functions - *Tianlei*
# 4. Parse input string into math functions - *Xincheng*
# 5. Set up testing suites for each function and connect it with TravisCI/CodeCov - *Bianca*
# 6. GUI implementation - *Yilan*
# 7. Documentation update - *Everyone*
#
# Note: Next meeting 11/19 3:30pm

# %% [markdown]
# ## Milestone 2 Progress
# Everyone - discussed in group meeting about the pseudocode for autoDiff and agreed on what to implement for project extensions
#
# Tianlei - finished M2a and checked error with TravisCI
#
# Yilan - updated extension and application of the project
#
# Xincheng - updated documentation of pseudocode
#
# Bianca - researched best testing practices
